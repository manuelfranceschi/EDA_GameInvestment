# %% [markdown]
# # Script presentación
# LA INDUSTRIA DEL VIDEOJUEGO
# antes me gustaría dar un poco de contexto en
# ***Empieza la presentación***
#
# La industria del videojuego: representa hoy por hoy uno de los sectores de mayor recaudación del entretenimiento, teniendo un valor global sel sector de 400 mil millones de dolares o, dicho de otro modo, vale casi más del doble que la industria del cine y la música juntos.
#
# Por ello, no es raro pensar que las cifras de ventas de estos juegos que llegan al mercado puedan ser muy altas. Por ejemplo:
#
# ***Se muestra una grafica de los videojuegos más vendidos***

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# + Minecraft, Terraria, Human Fall flat: juegos indie
# + GTA 5 y RDR2, nombre muy sonado de una desarrolladora de exito
# + PlayerUnkowns, juego multijugador
# + Skyrim y The Witcher 3, Zelda: RPG
# + COD: Franquicia anual consolidada en la industria

# %% [markdown]
# * Call of Duty, franquicia consolidada, vende muy bien a pesar de critica y repetitividad en varias entregas. como pequeño dato:
# * copia y pega de la entrega anterior <br>
# * nota media de 5,6/10
# * segundo juego más vendido en estados unidos

# %% [markdown]
# <p align="center">
#     <img src="./img/codmw3.webp">
# <p>

# %% [markdown]
# # Como invertir en la industria del videojuego

# %% [markdown]
# Para adentrarnos en el tema, hagamos de cuentas que somos un pequeño inversor que ve futuro en el mercado de los videojuegos. Cualquiera diria que los juegos más grandes son las mejores inversiones, pero vemos que hay juegos de todo tipo de escala y desarrolladoras que han ido evolucionando.

# %% [markdown]
# Teniendo en cuenta el gráfico anterior, nos hacemos las siguientes preguntas

# %% [markdown]
# + ¿Un videojuego exitoso en cuanto a critica representa el éxito en cuanto a ventas?
# + ¿Importa el género de un videojuego?
# + ¿La fecha de lanzamiento de un videojuego es un elemento clave para máximizar ingresos?
# + ¿Se pueden tener en cuenta otros parámetros para medir el éxito?

# %% [markdown]
# Y es que para responder estas preguntas, tendremos en cuenta los juegos con mayor recaudación de Steam 2024 en Steam para hacer este análisis.

# %% [markdown]
# # ¿Un videojuego exitoso en cuanto a critica representa el éxito en cuanto a ventas?

# %% [markdown]
# Aquí tendremos en cuenta tres factores: el tipo de publisher, las ventas y la media de las notas recibidas por los usuarios

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Vemos que gran parte de los juegos se concentran en este punto, suponiendo que, aunque tengan mejor o peor nota, realmente

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# + Porque un juego tenga buena nota no necesariamente va a vender más
# 1 de cada 100 juegos vende más de un millón de copias
# + Quizas los juegos indies no aportan tanto presupuesto en marketing como si lo hacen videojuegos con un presupuesto más elevado
#
# Teniendo en cuenta estas consideraciones, podemos decir que los juegos independientes pueden ser una oportunidad de negocio ya que por regla general son más baratos de producir, suelen ser mejor valorados y pueden tener más visibilidad si se considera una buena campaña de marketing.
#
# Así que, nos hacemos la siguiente pregunta

# %% [markdown]
# ¿Cuan rentables son los juegos independientes?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Por ello, resolvamos la siguiente hipotesis
# ¿Puede un juego independiente ser rentable?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
